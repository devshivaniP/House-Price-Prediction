# %%
import pandas

# %%
Raw_Housing_Data = pandas.read_csv("1._Regression_-_Module_-_(Housing_Prices)[1].csv")

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Raw_Housing_Data['Sale Price'], color = 'black')
plt.ylabel("Record Number")
plt.xlabel("Sale Price")
plt.title("Graph For Sale Price")
plt.show()

# %%
Raw_Housing_Data.groupby('Condition of the House')['ID'].count()
# Out:
# Condition of the House
# Bad             30
# Excellent     1701
# Fair         14031
# Good          5679
# Okay           172
# Name: ID, dtype: int64

# %%
values = (3000,1701,14031,5679,172)
labels = ('Bad','Excellent','Fair','Good','Okay')
plt.pie(values, labels = labels, shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x23b886c9dd0>,
# ...
#  [Text(1.020143713513219, 0.41146907997984455, 'Bad'),
#   Text(0.6089265973772948, 0.9160831834536153, 'Excellent'),
#   Text(-1.0881421528210475, 0.16107965499707377, 'Fair'),
#   Text(0.7899229331185057, -0.7655205808686382, 'Good'),
#   Text(1.099734279579021, -0.024176730937238537, 'Okay')])

# %%
values = (30,1701,14031,5679,172)
labels = ('Bad','Excellent','Fair','Good','Okay')
plt.bar(labels,values,color = 'Blue')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.scatter(x = Raw_Housing_Data['Condition of the House'], y = Raw_Housing_Data['Sale Price'], color = 'purple')
plt.xlabel("Condition")
plt.ylabel("Selling Price")
plt.title("Selling Price Vs. Condition of the House")
plt.show()

# %%
plt.hist(Raw_Housing_Data['Zipcode'], bins=10)
# Out:
# (array([2857., 4384., 3345., 1699.,  351., 4259., 1810., 1134., 1040.,
#          733.]),
#  array([98001. , 98020.8, 98040.6, 98060.4, 98080.2, 98100. , 98119.8,
#         98139.6, 98159.4, 98179.2, 98199. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(Raw_Housing_Data['Sale Price'])
